# %% [markdown]
# # Import Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/rusamijan/03-2023 Instacart Basket Analysis'

# %% [markdown]
# # Import orders_products_merged.pkl

# %%
df_ords_prod_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %% [markdown]
# # Minimizing data just 1000k

# %%
df = df_ords_prod_merged[:1000000]

# %% [markdown]
# # Create function 'price_label'

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # apply the function "price label" then save to a new data frame

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/fb/kyc5hp2j5z9bg9xqqyl73f2c0000gn/T/ipykernel_2096/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %% [markdown]
# # Check the value in the column

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %% [markdown]
# # Check the most expensive product

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # Create some conditions with loc()

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/fb/kyc5hp2j5z9bg9xqqyl73f2c0000gn/T/ipykernel_2096/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %% [markdown]
# # Check column

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # Create some conditions with the whole data with loc()

# %%
df_ords_prod_merged.loc[df_ords_prod_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prod_merged.loc[(df_ords_prod_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prod_merged.loc[df_ords_prod_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prod_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21104410
# Low-range product     10126321
# Mid-range product       756450
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # Check what is the busiest day

# %%
df_ords_prod_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# The value 0 means Saturday. This value has the highest frequency, which means that Saturday is the busiest day.

# %% [markdown]
# A value of 4, here, refers to Wednesday, meaning that Wednesday is the slowest day when it comes to Instacart app orders.

# %% [markdown]
# # Create a new column "busiest day"

# %% [markdown]
# that will contain one of three different values:  “Busiest day,” “Least busy,” and “Regularly busy.”

# %%
result = []

for value in df_ords_prod_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %% [markdown]
# # Show the result

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# # Combining it with df_ords_prod_merged dataframe

# %%
df_ords_prod_merged['busiest_day']=result

# %%
df_ords_prod_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
df_ords_prod_merged['busiest_day']
# Out:
# 0           Regularly busy
# 1           Regularly busy
# 2           Regularly busy
# 3               Least busy
# 4               Least busy
#                  ...
# 32404854    Regularly busy
# 32404855    Regularly busy
# 32404856    Regularly busy
# 32404857    Regularly busy
# 32404858        Least busy
# Name: busiest_day, Length: 32404859, dtype: object

# %% [markdown]
# # Task 4.7

# %%
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# # Checking which one busiest and slowest

# %%
df_ords_prod_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# Busiest days are 0 (sat) and 1(sun) and Slowest days are 3(tue) and 4(wed)

# %% [markdown]
# # Create the two busiest days of the week and the two slowest days

# %%
result2 = []

for value in df_ords_prod_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result2.append("Busiest Days")
  elif value == 3 or value == 4:
    result2.append("Slowest Days")
  else:
    result2.append("Regular Days")

# %% [markdown]
# # Merged to df_ords_prod_merged

# %%
df_ords_prod_merged['busiest_days']=result2

# %% [markdown]
# # Print frequency

# %%
df_ords_prod_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regular Days    12916111
# Busiest Days    11864412
# Slowest Days     7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# # Identify the busiest hours of the day

# %%
df_ords_prod_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# Most orders = (10,11,14,15,13,12,16,9), Average orders = (17,8,18,19,20,7,21,22), Fewest orders = (23,6,0,1,5,2,4,3)

# %% [markdown]
# # Create a new column "Busiest_period_of_day"

# %%
result3 = []

for value in df_ords_prod_merged["order_hour_of_day"]:
  if value in [10,11,14,15,13,12,16,9]:
    result3.append("Most Orders")
  elif value in [23,6,0,1,5,2,4,3]:
    result3.append("Fewest orders")
  else:
    result3.append("Average orders")

# %%
df_ords_prod_merged['busiest_period_of_day']=result3

# %% [markdown]
# # Print the frequency

# %%
df_ords_prod_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most Orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# # Check these new columns

# %%
print('Output of the orders_day_of_week and the busiest_days column:\n', df_ords_prod_merged[['orders_day_of_week', 'busiest_days']].head(10))
# Out:
# Output of the orders_day_of_week and the busiest_days column:
#     orders_day_of_week  busiest_days
# 0                   2  Regular Days
# 1                   3  Slowest Days
# 2                   3  Slowest Days
# 3                   4  Slowest Days
# 4                   4  Slowest Days
# 5                   2  Regular Days
# 6                   1  Busiest Days
# 7                   1  Busiest Days
# 8                   1  Busiest Days
# 9                   4  Slowest Days

# %%
print('Output of the order_hour_of_day and the busiest_period_of_day column:\n', df_ords_prod_merged[['order_hour_of_day', 'busiest_period_of_day']].head(10))
# Out:
# Output of the order_hour_of_day and the busiest_period_of_day column:
#     order_hour_of_day busiest_period_of_day
# 0                  8        Average orders
# 1                  7        Average orders
# 2                 12           Most Orders
# 3                  7        Average orders
# 4                 15           Most Orders
# 5                  7        Average orders
# 6                  9           Most Orders
# 7                 14           Most Orders
# 8                 16           Most Orders
# 9                  8        Average orders

# %%
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# # Export df_ords_prod_merged in .pkl

# %%
df_ords_prod_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_update.pkl'))

# %%
df_ords_prod_merged.shape
# Out:
# (32404859, 18)
